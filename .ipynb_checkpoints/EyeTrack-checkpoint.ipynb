# %%
import os
import h5py
import cv2

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load(dbname, dataset):
    '''
    dbname is the path to the database hdf file, dataset is the dataset name.
    returns a pandas dataframe and a dictionary with meta data for the dataset.
    '''
    attrs = None
    with h5py.File(dbname) as f:
        if dataset not in f.keys():
            raise ValueError('Can\'t find dataset. Available keys are: ' + str(f.keys()))
        try:
            df = pd.DataFrame(dict((k, f[dataset][k][:].ravel()) for k in f[dataset].keys()))
        except ValueError:
            raise RuntimeError('Not all fields have the same length:' +
                str(dict((k, f[dataset][k][:].ravel().shape) for k in f[dataset].keys())))
        if len(f[dataset].attrs.keys())>0:
            attrs = dict((k, f[dataset].attrs[k]) for k in  f[dataset].attrs.keys())
    return df, attrs

# %%
Data, attrs = load("etdb_v1.0.hdf5", "Face Discrim.")

# %%
Counts = [1]
j = 1

for i in np.arange(1, Data.shape[0]) :
    if all(Data.iloc[i-1, [0, 11]] == Data.iloc[i, [0, 11]]) : j += 1
    else : j = 1
    Counts.append(j)

Data['counts'] = Counts

# %%
Data
# Out:
#         SUBJECTINDEX  category  chain  condition  dataset_nr   end  \
# 0                  6      21.0      2      12375          18   391
# 1                  6      21.0      2      12375          18  1498
# 2                  6      21.0      2      18000          18   161
# 3                  6      21.0      2      18000          18   893
# 4                  6      21.0      2      18000          18  1443
# 5                  6      21.0      1          0          18   330
# 6                  6      21.0      1          0          18   944
# 7                  6      21.0      1          0          18  1499
# 8                  6      21.0      1      -5625          18   369
# 9                  6      21.0      1      -5625          18   655
# 10                 6      21.0      1      -5625          18  1275
# 11                 6      21.0      1      -5625          18  1498
# 12                 6      21.0      1          0          18   345
# 13                 6      21.0      1          0          18  1052
# 14                 6      21.0      1          0          18  1497
# 15                 6      21.0      1          0          18   458
# 16                 6      21.0      1          0          18   721
# 17                 6      21.0      1          0          18   950
# 18                 6      21.0      1          0          18  1250
# 19                 6      21.0      1          0          18  1497
# 20                 6      21.0      1      -7875          18   324
# 21                 6      21.0      1      -7875          18   516
# 22                 6      21.0      1      -7875          18   749
# 23                 6      21.0      1      -7875          18   894
# 24                 6      21.0      1      -7875          18  1198
# 25                 6      21.0      1      -7875          18  1498
# 26                 6      21.0      1          0          18   441
# 27                 6      21.0      1          0          18   884
# 28                 6      21.0      1          0          18  1226
# 29                 6      21.0      1          0          18  1498
# ...              ...       ...    ...        ...         ...   ...
# 100418            36      21.0      2      18000          18   824
# 100419            36      21.0      2      18000          18  1499
# 100420            36      21.0      2      -9000          18   159
# 100421            36      21.0      2      -9000          18   464
# 100422            36      21.0      2      -9000          18   753
# 100423            36      21.0      2      -9000          18  1497
# 100424            36      21.0      2      18000          18   586
# 100425            36      21.0      2      18000          18  1498
# 100426            36      21.0      2      18000          18   186
# 100427            36      21.0      2      18000          18   668
# 100428            36      21.0      2      18000          18   875
# 100429            36      21.0      2      18000          18  1066
# 100430            36      21.0      2      18000          18  1497
# 100431            36      21.0      2      18000          18  1243
# 100432            36      21.0      2      18000          18  1498
# 100433            36      21.0      2      18000          18   103
# 100434            36      21.0      2      18000          18   221
# 100435            36      21.0      2      18000          18  1176
# 100436            36      21.0      2      18000          18  1497
# 100437            36      21.0      2      -9000          18  1497
# 100438            36      21.0      2      18000          18   466
# 100439            36      21.0      2      18000          18  1497
# 100440            36      21.0      2      -9000          18   519
# 100441            36      21.0      2      -9000          18   609
# 100442            36      21.0      2      -9000          18  1497
# 100443            36      21.0      2      -9000          18   157
# 100444            36      21.0      2      -9000          18   929
# 100445            36      21.0      2      -9000          18  1272
# 15          1
# 16          2
# 17          3
# 18          4
# 19          5
# 20          1
# 21          2
# 22          3
# 23          4
# 24          5
# 25          6
# 26          1
# 27          2
# 28          3
# 29          4
# ...       ...
# 100418      2
# 100419      3
# 100420      1
# 100421      2
# 100422      3
# 100423      4
# 100424      1
# 100425      2
# 100426      1
# 100427      2
# 100428      3
# 100429      4
# 100430      5
# 100431      1
# 100432      2
# 100433      1
# 100434      2
# 100435      3
# 100436      4
# 100437      1
# 100438      1
# 100439      2
# 100440      1
# 100441      2
# 100442      3
# 100443      1
# 100444      2
# 100445      3
# 100446      4
# 100447      1
#
# [100448 rows x 15 columns]

# %%
Data.columns.values
# Out:
# array(['SUBJECTINDEX', 'category', 'chain', 'condition', 'dataset_nr',
#        'end', 'filenumber', 'fix', 'isref', 'phase', 'start', 'trial', 'x',
#        'y', 'counts'], dtype=object)

# %%
Data.counts.value_counts()
# Out:
# 1     23144
# 2     22775
# 3     21262
# 4     17378
# 5     10728
# 6      4036
# 7       930
# 8       147
# 9        36
# 10        7
# 11        2
# 14        1
# 13        1
# 12        1
# Name: counts, dtype: int64

# %%
21    10660
5     10289
1     10215
17    10146
29     9292
13     9065

# %%
Order = Data[Data['filenumber']==Num]

# %%
sns.distplot(Subject['x'], hist=False)
plt.show()

# %%
adr = '21/' + str(Num) + '.png'
img = cv2.imread(adr, 1)
img = cv2.resize(img, (1600, 1200), interpolation=cv2.INTER_CUBIC)

# %%
def transparent_cmap(cmap, N=255):
    mycmap = cmap
    mycmap._init()
    mycmap._lut[:,-1] = np.linspace(0, 0.8, N+4)
    return mycmap

mycmap = transparent_cmap(plt.cm.Reds)

# %%
plt.imshow(img)
plt.xlim(0, 1600)
plt.ylim(1200, 0)

ax = sns.kdeplot(FileNum['x'], FileNum['y'], shade = True, cmap = mycmap)
ax.patch.set_facecolor('white')
ax.collections[0].set_alpha(0)

plt.show()
# Out:
#   File "<ipython-input-79-c4575e219621>", line 5
#     fig.add_subplot(211)
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# #### Gaze map by different faces
#
# pictures used : (21, 5, 1, 17, 29, 13) based on the frequency.
#
# Pic|Freq
# -|-
# 21|    10660
# 5|     10289
# 1|     10215
# 17|    10146
# 29|     9292
# 13|     9065

# %%
fig = plt.figure()

for i, Num in enumerate((21, 5, 1, 17, 29, 13)):
    
    FileNum = Data[Data['filenumber']==Num]
    adr = '21/' + str(Num) + '.png'
    img = cv2.imread(adr, 1)
    img = cv2.resize(img, (1600, 1200), interpolation=cv2.INTER_CUBIC)
    
    fig_num = "23" + str(i+1)
    fig.add_subplot(int(fig_num))

    plt.imshow(img)
    plt.xlim(0, 1600)
    plt.ylim(1200, 0)
    plt.axis('off')

    ax = sns.kdeplot(FileNum['x'], FileNum['y'], shade = True, cmap = mycmap)
    ax.patch.set_facecolor('white')
    ax.collections[0].set_alpha(0)

plt.show()

# %% [markdown]
# #### Gaze map by fixation order

# %%
fig = plt.figure()

for i, Order in enumerate((1, 3, 5, 7)):
    
    GazeOrder = Data[Data['counts']==Order]
    adr = '21/1.png'
    img = cv2.imread(adr, 1)
    img = cv2.resize(img, (1600, 1200), interpolation=cv2.INTER_CUBIC)
    
    fig_num = "22" + str(i+1)
    fig.add_subplot(int(fig_num))

    plt.imshow(img)
    plt.xlim(0, 1600)
    plt.ylim(1200, 0)
    plt.axis('off')

    ax = sns.kdeplot(GazeOrder['x'], GazeOrder['y'], shade = True, cmap = mycmap)
    ax.patch.set_facecolor('white')
    ax.collections[0].set_alpha(0)

plt.show()
